# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_paths = {
    "zillow": "./data/out/zillow.csv",
    "zillow+demographics": "./data/out/zillow+demographics.csv",
    "zillow_market_2018+": "./data/out/zillow_market_2018+.csv",
    "data.gov_personal_income": "./data/in/data.gov_personal_income.csv",
}

# %% [markdown]
# ## Demographics

# %% [markdown]
# #### Helper functions

# %%
df = pd.read_csv(data_paths["data.gov_personal_income"])
df["Year"] = df["Year"].astype(int)
df["Personal Income"] = df["Personal Income"].apply(lambda x: x.replace("$", "\\$"))

df.head()
# Out:
#    Year       Age Gender  Educational Attainment   Race       Personal Income  \
# 0  2008  00 to 17   Male  No high school diploma  White    \$5,000 to \$9,999
# 1  2008  00 to 17   Male  No high school diploma  White  \$10,000 to \$14,999
# 2  2008  00 to 17   Male  No high school diploma  White  \$15,000 to \$24,999
# 3  2008  00 to 17   Male  No high school diploma  White  \$25,000 to \$34,999
# 4  2008  00 to 17   Male  No high school diploma  White  \$35,000 to \$49,999
#
#    Population Count
# 0              9869
# 1              3191
# 2              1642
# 3               332
# 4               135

# %%
def reorder_column(df, col, order):
    df[col] = pd.Categorical(df[col], categories=order, ordered=True)
    df = df.sort_values(by=col).reset_index(drop=True)
    return df

income_order = [
    "No Income",
    "\\$5,000 to \\$9,999",
    "\\$10,000 to \\$14,999",
    "\\$15,000 to \\$24,999",
    "\\$25,000 to \\$34,999",
    "\\$35,000 to \\$49,999",
    "\\$50,000 to \\$74,999",
    "\\$75,000 and over",
]

edu_order = [
    "No high school diploma",
    "High school or equivalent",
    "Some college, less than 4-yr degree",
    "Bachelor's degree or higher",
]

race_order = ["White", "African American", "Asian", "Hispanic", "Other"]

demographics_year_x_ticks = np.arange(2008, 2024, dtype=int)

# %% [markdown]
# ### Gender/Income/Population

# %%
gpc_df = (
    df[(df["Age"] != "00 to 17") & (df["Age"] != "65 to 80+")]
    .drop(columns=["Year", "Age", "Educational Attainment", "Race"])
    .groupby(["Gender", "Personal Income"])
    .sum()
    .reset_index()
    .copy()
)
gpc_df.head()
# Out:
#    Gender       Personal Income  Population Count
# 0  Female             No Income          37060577
# 1  Female  \$10,000 to \$14,999          16227232
# 2  Female  \$15,000 to \$24,999          23990148
# 3  Female  \$25,000 to \$34,999          18301334
# 4  Female  \$35,000 to \$49,999          19757631

# %%
gpc_df = reorder_column(gpc_df, "Personal Income", income_order)
gpc_df.head()
# Out:
#    Gender       Personal Income  Population Count
# 0  Female             No Income          37060577
# 1    Male             No Income          20221603
# 2  Female    \$5,000 to \$9,999          15293973
# 3    Male    \$5,000 to \$9,999          11090273
# 4  Female  \$10,000 to \$14,999          16227232

# %%
gpc_male = (
    gpc_df[gpc_df["Gender"] == "Male"]
    .drop(columns=["Gender"])
    .reset_index(drop=True)
    .copy()
)
gpc_fmle = (
    gpc_df[gpc_df["Gender"] == "Female"]
    .drop(columns=["Gender"])
    .reset_index(drop=True)
    .copy()
)

# %%
gpc_butterfly = gpc_male.merge(
    gpc_fmle, on="Personal Income", suffixes=("_Male", "_Female")
)
gpc_butterfly["Population Count_Male"] *= -1
plt.figure(figsize=(8, 4))
labels = gpc_butterfly["Personal Income"].astype(str)

sns.barplot(
    data=gpc_butterfly,
    y=labels,
    x="Population Count_Female",
    color="salmon",
    label="Female",
    errorbar=None,
)

sns.barplot(
    data=gpc_butterfly,
    y=labels,
    x="Population Count_Male",
    color="royalblue",
    label="Male",
    errorbar=None,
)

plt.axvline(0, color="black", linewidth=1)
plt.xlabel("Population Count (million)")
plt.ylabel("")
plt.title("Population Distribution by Income (Male vs. Female)")
plt.legend(loc="lower right")
plt.xticks(
    np.linspace(-40_000_000, 40_000_000, 9),
    labels=[int(x) for x in np.abs(np.linspace(-40, 40, 9))],
)

plt.show()

# %% [markdown]
# ### Gender/Education/Population

# %%
gec_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Year", "Age", "Personal Income", "Race"])
    .groupby(["Gender", "Educational Attainment"])
    .sum()
    .reset_index()
    .copy()
)
gec_df.head()
# Out:
#    Gender               Educational Attainment  Population Count
# 0  Female          Bachelor's degree or higher          54135483
# 1  Female            High school or equivalent          35266063
# 2  Female               No high school diploma          25630712
# 3  Female  Some college, less than 4-yr degree          57067759
# 4    Male          Bachelor's degree or higher          44005568

# %%
gec_df = reorder_column(gec_df, "Educational Attainment", edu_order)
gec_df.head()
# Out:
#    Gender               Educational Attainment  Population Count
# 0  Female               No high school diploma          25630712
# 1    Male               No high school diploma          31110736
# 2  Female            High school or equivalent          35266063
# 3    Male            High school or equivalent          42758985
# 4  Female  Some college, less than 4-yr degree          57067759

# %%
gec_male = (
    gec_df[gec_df["Gender"] == "Male"]
    .drop(columns=["Gender"])
    .reset_index(drop=True)
    .copy()
)
gec_fmle = (
    gec_df[gec_df["Gender"] == "Female"]
    .drop(columns=["Gender"])
    .reset_index(drop=True)
    .copy()
)

# %%
gec_butterfly = gec_male.merge(
    gec_fmle, on="Educational Attainment", suffixes=("_Male", "_Female")
)
gec_butterfly["Population Count_Male"] *= -1
plt.figure(figsize=(8, 4))
labels = gec_butterfly["Educational Attainment"].astype(str)

sns.barplot(
    data=gec_butterfly,
    y=labels,
    x="Population Count_Female",
    color="salmon",
    label="Female",
    errorbar=None,
)

sns.barplot(
    data=gec_butterfly,
    y=labels,
    x="Population Count_Male",
    color="royalblue",
    label="Male",
    errorbar=None,
)

plt.axvline(0, color="black", linewidth=1)
plt.xlabel("Population Count (million)")
plt.ylabel("")
plt.title("Population Distribution by Education (Male vs. Female)")
plt.legend(loc="upper right")
plt.xticks(
    np.linspace(-60_000_000, 60_000_000, 9),
    labels=[int(x) for x in np.abs(np.linspace(-60, 60, 9))],
)

plt.show()

# %% [markdown]
# ### Race/Population

# %%
rp_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Year", "Age", "Personal Income", "Gender", "Educational Attainment"])
    .groupby(["Race"])
    .sum()
    .reset_index()
    .copy()
)
rp_df = rp_df.sort_values(by="Population Count", ascending=True)
rp_df.head()
# Out:
#                Race  Population Count
# 3             Other          12474688
# 0  African American          19996223
# 1             Asian          50023756
# 4             White         125066725
# 2          Hispanic         136424136

# %%
plt.figure(figsize=(8, 4))
sns.barplot(
    data=rp_df,
    y="Race",
    x="Population Count",
)
plt.xticks(
    np.linspace(0, 200_000_000, 9),
    labels=[int(x) for x in np.abs(np.linspace(0, 200, 9))],
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Education/Income/Population

# %%
eip_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Year", "Age", "Gender", "Race"])
    .groupby(["Educational Attainment", "Personal Income"])
    .sum()
    .reset_index()
    .copy()
)
eip_df.head()
# Out:
#         Educational Attainment       Personal Income  Population Count
# 0  Bachelor's degree or higher             No Income           9178207
# 1  Bachelor's degree or higher  \$10,000 to \$14,999           4307932
# 2  Bachelor's degree or higher  \$15,000 to \$24,999           7970400
# 3  Bachelor's degree or higher  \$25,000 to \$34,999           7707376
# 4  Bachelor's degree or higher  \$35,000 to \$49,999          11768083

# %%
eip_df = reorder_column(eip_df, "Educational Attainment", edu_order)
eip_df = reorder_column(eip_df, "Personal Income", income_order)

# %%
eip_pivot = eip_df.pivot(
    columns="Educational Attainment",
    index="Personal Income",
    values="Population Count"
)

plt.figure(figsize=(9,7))
sns.heatmap(
    eip_pivot,
    cmap="RdBu",
    annot=True,
    fmt=",d",
    cbar_kws={'label': 'Population Count'}
)

plt.title("Population Distribution Heatmap: Education vs Income")
plt.xlabel("Personal Income")
plt.ylabel("Educational Attainment")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Race/Income/Population

# %%
rip_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Year", "Age", "Gender", "Educational Attainment"])
    .groupby(["Race", "Personal Income"])
    .sum()
    .reset_index()
    .copy()
)
rip_df.head()
# Out:
#                Race       Personal Income  Population Count
# 0  African American             No Income           3395072
# 1  African American  \$10,000 to \$14,999           2205478
# 2  African American  \$15,000 to \$24,999           2608562
# 3  African American  \$25,000 to \$34,999           2147792
# 4  African American  \$35,000 to \$49,999           2537826

# %%
rip_df = reorder_column(rip_df, "Personal Income", income_order)

# %%
rip_pivot = rip_df.pivot(
    columns="Race",
    index="Personal Income",
    values="Population Count"
)

plt.figure(figsize=(9, 7))
sns.heatmap(
    rip_pivot,
    cmap="RdBu",
    annot=True,
    fmt=",d",
    cbar_kws={'label': 'Population Count'}
)

plt.title("Population Distribution Heatmap: Race vs Income")
plt.xlabel("Personal Income")
plt.ylabel("Race")

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Income/Year

# %%
iy_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Gender", "Age", "Educational Attainment", "Race"])
    .groupby(["Year", "Personal Income"])
    .sum()
    .reset_index()
    .copy()
)
iy_df.head()
# Out:
#    Year       Personal Income  Population Count
# 0  2008             No Income           3015519
# 1  2008  \$10,000 to \$14,999           2022443
# 2  2008  \$15,000 to \$24,999           3219749
# 3  2008  \$25,000 to \$34,999           2433391
# 4  2008  \$35,000 to \$49,999           2782413

# %%
iy_df = reorder_column(iy_df, "Personal Income", income_order)
iy_df = iy_df.sort_values(["Year", "Personal Income"])
iy_df.head()
# Out:
#     Year       Personal Income  Population Count
# 0   2008             No Income           3015519
# 25  2008    \$5,000 to \$9,999           1756918
# 34  2008  \$10,000 to \$14,999           2022443
# 63  2008  \$15,000 to \$24,999           3219749
# 71  2008  \$25,000 to \$34,999           2433391

# %%
plt.figure(figsize=(12, 5))

sns.lineplot(
    data=iy_df,
    x="Year",
    y="Population Count",
    hue="Personal Income",
    hue_order=income_order,
    palette="colorblind",
    linewidth=3,
)

plt.xlabel("Year")
plt.xticks(demographics_year_x_ticks)
plt.ylabel("Population Count (million)")
plt.title("Income Distribution Over the Years")
plt.legend(
    title="Personal Income",
    bbox_to_anchor=(1.05, 1),
    loc="upper left",
)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Education/Year

# %%
ey_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Gender", "Age", "Race", "Personal Income"])
    .groupby(["Year", "Educational Attainment"])
    .sum()
    .reset_index()
    .copy()
)
ey_df.head()
# Out:
#    Year               Educational Attainment  Population Count
# 0  2008          Bachelor's degree or higher           5484976
# 1  2008            High school or equivalent           4474165
# 2  2008               No high school diploma           3932844
# 3  2008  Some college, less than 4-yr degree           6856966
# 4  2009          Bachelor's degree or higher           5563219

# %%
ey_df = reorder_column(ey_df, "Educational Attainment", reversed(edu_order))

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(ey_df, x="Year", y="Population Count", hue="Educational Attainment", errorbar=None, palette="colorblind", linewidth=3)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Educational Attainment")
plt.yticks([3000000, 4000000, 5000000, 6000000, 7000000], [3,4,5,6,7])
plt.xticks(demographics_year_x_ticks)
plt.ylabel("Population Count (in millions)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Race/Year

# %%
ry_df = (
    df[
        (df["Age"] != "00 to 17")
        & (df["Age"] != "65 to 80+")
        & (df["Educational Attainment"] != "Children under 15")
    ]
    .drop(columns=["Gender", "Age", "Educational Attainment", "Personal Income"])
    .groupby(["Year", "Race"])
    .sum()
    .reset_index()
    .copy()
)
ry_df.head()
# Out:
#    Year              Race  Population Count
# 0  2008  African American           1267932
# 1  2008             Asian           2735599
# 2  2008          Hispanic           7412773
# 3  2008             Other            594375
# 4  2008             White           8738272

# %%
race_order
# Out:
# ['White', 'African American', 'Asian', 'Hispanic', 'Other']

# %%
ry_df = reorder_column(ry_df, "Race", ["Hispanic", "White", "Asian", "African American", "Other"])

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(ry_df, x="Year", y="Population Count", hue="Race", errorbar=None, palette="colorblind", linewidth=3)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Race")
yticks = np.arange(0, 10000000, 1000000)
plt.yticks(yticks, yticks//1000000)
plt.xticks(demographics_year_x_ticks)
plt.ylabel("Population Count (in millions)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
